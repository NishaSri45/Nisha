# %%
import pandas as pd
df = pd.read_csv('House_Rent_Dataset.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rent_df=pd.read_csv("House_Rent_Dataset.csv")
rent_df.sample(5)
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 1279  2022-07-07    1  23000   440  Ground out of 4  Carpet Area
# 2073  2022-06-27    2  13000   600       1 out of 2   Super Area
# 2530  2022-05-10    1   8000   500  Ground out of 3   Super Area
# 3921  2022-07-03    3  25000   919      8 out of 13  Carpet Area
# 2205  2022-07-06    2  16500  1100       2 out of 3   Super Area
#
#                         Area Locality       City Furnishing Status  \
# 1279                in Kandivali West     Mumbai    Semi-Furnished
# 2073      Ramaswami Palya kammanhalli  Bangalore    Semi-Furnished
# 2530                 Dwarka Sector 23      Delhi    Semi-Furnished
# 3921  Rajendra Nagar, Outer Ring Road  Hyderabad    Semi-Furnished
# 2205                       Hbr Layout  Bangalore    Semi-Furnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 1279         Bachelors         1    Contact Agent
# 2073  Bachelors/Family         2    Contact Owner
# ...

# %% [raw]
# rent_df.shape

# %% [raw]
# rent_df.columns

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
rent_df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
rent_df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
rent_df.duplicated().sum()
# Out:
# 0

# %%
print("Mean house rent:",round(rent_df["Rent"].mean()))
print("")
# Out:
# Mean house rent: 34993

# %%
rent_df["Rent"].sort_values()[:5]
# Out:
# 4076    1200
# 285     1500
# 471     1800
# 2475    2000
# 146     2200
# Name: Rent, dtype: int64

# %%
sns.set_context("poster",font_scale= .8)
plt.figure(figsize=(20,6))
ax=rent_df["City"].value_counts().plot(kind='bar',color="crimson",rot=0)

# %%
sns.set_context("poster",font_scale= .8)
plt.figure(figsize=(20,6))
ax=rent_df["City"].value_counts().plot(kind='bar',color="crimson",rot=0)

# %%
for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x()+0.25,p.get_height()-100),ha='center',va='bottom',color='white')

# %%
sns.set_context("poster",font_scale= .8)
plt.figure(figsize=(20,6))
ax=rent_df["City"].value_counts().plot(kind='bar',color="crimson",rot=0)
for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x()+0.25,p.get_height()-100),ha='center',va='bottom',color='white')

# %%
sns.set_context("poster",font_scale= .8)
plt.figure(figsize=(20,6))
ax=rent_df["Tenant Preferred"].value_counts().plot(kind='bar',color="crimson",rot=0)

for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x()+0.25,p.get_height()-100),ha='center',va='bottom',color='white')

# %%
sns.set_context("poster",font_scale= .8)
plt.figure(figsize=(20,6))
ax=rent_df["Tenant Preferred"].value_counts().plot(kind='bar',color="crimson",rot=0)

# %%
for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x()+0.25,p.get_height()-100),ha='center',va='bottom',color='white')

# %%
sns.set_context("poster",font_scale= .8)
plt.figure(figsize=(20,6))
ax=rent_df["Furnishing Status"].value_counts().plot(kind='bar',color="crimson",rot=0)
for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x()+0.25,p.get_height()-100),ha='center',va='bottom',color='brown')

# %%
sns.set_context("poster",font_scale= .8)
plt.figure(figsize=(20,6))
ax=rent_df["Tenant Preferred"].value_counts().plot(kind='bar',color="crimson",rot=0)

for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x()+0.25,p.get_height()-100),ha='center',va='bottom',color='white')

# %%
plt.figure(figsize=(20,8))
counts=rent_df["City"].value_counts()
explode=(0,0,0,0.1,0,0)
counts.plot(kind='pie',explode=explode,autopct='%1.1f%%')
plt.axis('equal')
plt.legend(labels=counts.index,loc="best")
plt.show()

# %%
plt.figure(figsize=(20,8))
counts=rent_df["City"].value_counts()
explode=(0,0,0,0.1,0,0)
counts.plot(kind='pie',explode=explode,autopct='%1.1f%%')
plt.axis('equal')
plt.legend(labels=counts.index,loc="best")
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.ticklabel_format(style='plain')
plt.scatter(rent_df['Size'],rent_df["Rent"])
plt.xlabel("Size")
# Out:
# Text(0.5, 0, 'Size')

# %%
n_bins=20
plt.figure(figsize=(20,6))
rent_df["Size"].hist(bins=n_bins);

# %%
plt.figure(figsize=(20,6))
sns.heatmap(pd.crosstab(rent_df["Area Type"],rent_df["BHK"]))
# Out:
# <Axes: xlabel='BHK', ylabel='Area Type'>

# %%
plt.figure(figsize=(20,6))
sns.heatmap(pd.crosstab(rent_df["Rent"],rent_df["Size"]))
# Out:
# <Axes: xlabel='Size', ylabel='Rent'>

# %%
rent_df.plot()
# Out:
# <Axes: >

# %%
rent_df["BHK"].plot()
# Out:
# <Axes: >

# %%
rent_df['Bathroom'].plot(legend=True)
# Out:
# <Axes: >

# %%
rent_df.plot(title='sample plot',figsize=(15,10))
# Out:
# <Axes: title={'center': 'sample plot'}>

# %%
explode=(0,0,0,0.1,0,0)
rent_df["City"].value_counts().plot(kind='pie',figsize=(20,8),autopct='%1.1f%%',explode=explode)
# Out:
# <Axes: ylabel='count'>

# %%
#deep copy copies the original it doesn't reflect changes made to the new/copied object in the object
#shallow copy copies from deep copy it stores the copy of the original object and points the reference to the object

# %%
#outlier analysis

data=pd.read_csv("House_Rent_Dataset.csv")
data_shallow=data
fig,axs = plt.subplots(2,3,figsize=(10,5))
plt1 = sns.boxplot(data_shallow['Rent'],ax = axs[0,0])
plt1 = sns.boxplot(data_shallow['Size'],ax = axs[0,1])
plt.tight_layout()

# %%
#outlier treatment for price
plt.boxplot(data.Rent)
Q1 = data.Rent.quantile(0.25)
Q3 = data.Rent.quantile(0.75)
IQR =Q3-Q1
housing=data[(data.Rent>=Q1 - 1.5*IQR)&(data.Rent<=Q3 + 1.5*IQR)]

# %%
plt.boxplot(data.Size)
Q1 = data.Size.quantile(0.25)
Q3 = data.Size.quantile(0.75)
IQR =Q3-Q1
housing=data[(data.Size>=Q1 - 1.5*IQR)&(data.Size<=Q3 + 1.5*IQR)]

# %%
plt.boxplot(data.BHK)
Q1 = data.BHK.quantile(0.25)
Q3 = data.BHK.quantile(0.75)
IQR =Q3-Q1
housing=data[(data.BHK>=Q1 - 1.5*IQR)&(data.BHK<=Q3 + 1.5*IQR)]

# %%
#Feature engineering of feature selection
x = data[:]
y = ['Rent']

# %%
housing
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
#Convert the data objects into numerical values for model building
#label encoder - convert the data
#split the dataset into x
#feature importance

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
import category_encoders as ce

# %%
pip install category_encoders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
housing_final=housing.drop(columns="Posted On")

# %%
x=housing_final.drop(columns="Rent")
y=housing_final["Rent"]#target

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4719 entries, 0 to 4745
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BHK                4719 non-null   int64
#  1   Size               4719 non-null   int64
#  2   Floor              4719 non-null   object
#  3   Area Type          4719 non-null   object
#  4   Area Locality      4719 non-null   object
#  5   City               4719 non-null   object
#  6   Furnishing Status  4719 non-null   object
#  7   Tenant Preferred   4719 non-null   object
#  8   Bathroom           4719 non-null   int64
#  9   Point of Contact   4719 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 405.5+ KB

# %%
encoder = ce.LeaveOneOutEncoder()
x=encoder.fit_transform(x,y)

# %%
x
# Out:
#       BHK  Size         Floor     Area Type  Area Locality          City  \
# 0       2  1100  13955.164740  18441.917831    6500.000000  11585.713462
# 1       2   800  17803.092784  18437.809367    3500.000000  11566.482692
# 2       2  1000  17813.402062  18439.041906   23600.000000  11572.251923
# 3       2   800  14284.615385  18441.917831   22000.000000  11585.713462
# 4       2   850  14291.246684  50379.347655   33871.883874  11590.521154
# ...   ...   ...           ...           ...            ...           ...
# 4741    2  1000  21971.719512  50376.059623   16500.000000  20031.178114
# 4742    3  2000  25119.095477  18434.111750   33871.883874  20014.880093
# 4743    3  1750  21727.817073  50367.291539   30000.000000  20007.895227
# 4744    3  1500  33871.883874  50362.907497   43839.285714  19996.253783
# 4745    2  1000  18794.117647  50376.059623   15750.000000  20031.178114
#
#       Furnishing Status  Tenant Preferred  Bathroom  Point of Contact
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
model_rfr=RandomForestRegressor(n_estimators=7)
model_dt=DecisionTreeRegressor()
model_lr=LinearRegression()

# %%
models=[model_rfr,model_dt,model_lr]

# %%
for model in models:
    print(f"fitting model: {model}")
    model.fit(x_train,y_train)
# Out:
# fitting model: RandomForestRegressor(n_estimators=7)
# fitting model: DecisionTreeRegressor()
# fitting model: LinearRegression()

# %%
for model in models:
    print(f"score of {model} for training data: {model.score(x_train,y_train)}")
# Out:
# score of RandomForestRegressor(n_estimators=7) for training data: 0.8061055826934802
# score of DecisionTreeRegressor() for training data: 1.0
# score of LinearRegression() for training data: 0.27463235411568987

# %%
for model in models:
    print(f"score of {model} for testing data: {model.score(x_test,y_test)}")
# Out:
# score of RandomForestRegressor(n_estimators=7) for testing data: 0.791925338813334
# score of DecisionTreeRegressor() for testing data: 0.8938764196467757
# score of LinearRegression() for testing data: 0.5525845020786124

# %%
#feature importance to establish the feature importance of each feature in decision making
fs= model_rfr.feature_importances_
feature_names= x.columns

# %%
feature_importances= pd.DataFrame(fs,feature_names).sort_values(by=0,ascending=False)
plt.figure(figsize=(12,9))
plt.title("Feature Importances")
plt.bar(x=feature_importances.index,height=feature_importances[0])
plt.xticks(rotation=90)
plt.show()

# %%
feature_importances
# Out:
#                           0
# Tenant Preferred   0.449593
# Point of Contact   0.250220
# City               0.102732
# Area Type          0.067385
# Bathroom           0.046180
# Furnishing Status  0.040438
# Size               0.035361
# Area Locality      0.005477
# BHK                0.001879
# Floor              0.000736

# %%
#ERROR METRICS-REGRESSION MODEL
#Mean_absolute_error
#Mean_squared_error
#root_mean_squared_error
#Regression best fit line score

# %%
def regression_results(y_true, y_pred):
    # Regression metrics
    mean_absolute_error = metrics.mean_absolute_error(y_true, y_pred) 
    mse = metrics.mean_squared_error(y_true, y_pred) 
    mean_squared_log_error = None
    
    # Handling negative values
    if (y_true >= 0).all() and (y_pred >= 0).all():
        mean_squared_log_error = metrics.mean_squared_log_error(y_true, y_pred)

    r2 = metrics.r2_score(y_true, y_pred)

    results = {
        'r2': round(r2, 4),
        'MAE': round(mean_absolute_error, 4),
        'MSE': round(mse, 4),
        'RMSE': round(np.sqrt(mse), 4),
        'mean_squared_log_error': round(mean_squared_log_error, 4) if mean_squared_log_error is not None else "N/A"
    }
    
    return results

for model in models:
    y_predicted = model.predict(x_test)

    print(f"Report: {model}")
    results = regression_results(y_test, y_predicted)
    for metric, value in results.items():
        print(f'{metric}: {value}')
    print("\n")
# Out:
# Report: RandomForestRegressor(n_estimators=7)
# r2: 0.7919
# MAE: 2221.0222
# MSE: 732369910.0785
# RMSE: 27062.3338
# mean_squared_log_error: 0.0188
#
#
# Report: DecisionTreeRegressor()
# r2: 0.8939
# MAE: 1785.7352
# MSE: 373528023.822
# RMSE: 19326.8731
# mean_squared_log_error: 0.0108
#
#
# Report: LinearRegression()
# r2: 0.5526
# MAE: 19100.5878
# MSE: 1574788809.515
# RMSE: 39683.6088
# mean_squared_log_error: N/A
